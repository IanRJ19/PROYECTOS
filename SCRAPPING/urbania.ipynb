# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from decouple import config
import time
import pandas as pd 

# Inicializar el driver de Selenium
driver = webdriver.Chrome()

# Ir a la página de inicio de LinkedIn
driver.get("https://urbania.pe/buscar/alquiler-de-departamentos-en-pueblo-libre--lima--lima?bedroomMin=3&coveredAreaMin=80&priceMax=2600&currencyId=6")


time.sleep(9)

# %%
job_elements = driver.find_elements(By.CSS_SELECTOR,"[data-qa='posting PROPERTY']")

jobs = []

# %%
job_elements
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="58a98cf08a74e55aee953c223cd6f54f", element="fa1d609b-ca21-42f0-81c5-9c7068fc859f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="58a98cf08a74e55aee953c223cd6f54f", element="f7f43542-3023-468a-8039-75b19e8ce6c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="58a98cf08a74e55aee953c223cd6f54f", element="9e3dd675-e092-44e9-beeb-f314960a8983")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="58a98cf08a74e55aee953c223cd6f54f", element="e05395b8-4b1f-4744-b4ff-24b156087348")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="58a98cf08a74e55aee953c223cd6f54f", element="fc722ea2-246f-4655-a45a-58b93279b5da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="58a98cf08a74e55aee953c223cd6f54f", element="e7ba73fc-74e8-4083-a185-3163b2973ab0")>,
# ...

# %%
for element in job_elements:
    print(element.text)
# Out:
# S/ 2,600
# (USD 685)
# S/ 250 Mantenimiento
# Av. Brasil
# Pueblo Libre, Lima
# 77 m²
# 80 m²
# 3 dorm.
# 2 baños
# 1 estac.
# Alquilo Bello Departamento en Pueblo Libre Limite con Jesús MaríaAlquilo Departamento cerca a la Brasil en edifico moderno con instalaciones de gas natura! Caracteristicas: - 01 Dormitorio Principal amplio con baño privado, walking closet, vista externa y balcón. - 2 Dormitorios secundarios con closet. - 02 Baños completos. - Amplio balcón. - Sala comedor amplia + Sala de estar. - Cocina estilo americana implementada con cocina + campana. - Lavandería con lavaseca y terma a gas. - Conexiones a gas (lavaseca + cocina + terma) - 01 estacionamiento costo adicional de 200. 00 soles. El edificio cuenta con 3 Área de parrilla, Gimnasio, Cine, Zona para niños.
# Super destacado
# Comparar
# Contactar
# S/ 2,400
# (USD 634)
# S/ 170 Mantenimiento
# Pueblo Libre, Lima
# 90 m²
# 90 m²
# 3 dorm.
# 2 baños
# 1 estac.
# ...

# %%
time.sleep(9)
# Iterar sobre los elementos de las ofertas de trabajo
for job_element in job_elements:
    title_elements = job_element.find_elements(By.CSS_SELECTOR,"[data-qa='POSTING_CARD_PRICE']")
    #company_elements = job_element.find_elements(By.CSS_SELECTOR,"[data-qa='POSTING_CARD_GALLERY']")
    location_elements = job_element.find_elements(By.CSS_SELECTOR,"[data-qa='POSTING_CARD_LOCATION']")
    featueres_elements = job_element.find_elements(By.CSS_SELECTOR,"[data-qa='POSTING_CARD_FEATURES']")
    descripcion_elements = job_element.find_elements(By.CSS_SELECTOR,"[data-qa='POSTING_CARD_DESCRIPTION']")
    
    title = title_elements[0].text if title_elements else None
    #company = company_elements[0].text if company_elements else None
    location = location_elements[0].text if location_elements else None
    features = featueres_elements[0].text if featueres_elements else None
    descripcion=descripcion_elements[0].text if descripcion_elements else None
    jobs.append({"title": title, "location": location,"caracteristicas":features,"descripcion":descripcion})


# Almacenar los datos en un DataFrame de Pandas
jobs_df = pd.DataFrame(jobs)

# %%
print(jobs_df.head(20))
# Out:
#        title                                      location  \
# 0   S/ 2,600                            Pueblo Libre, Lima
# 1   S/ 2,400                            Pueblo Libre, Lima
# 2   S/ 2,300                            Pueblo Libre, Lima
# 3   S/ 2,200                            Pueblo Libre, Lima
# 4   S/ 2,400                            Pueblo Libre, Lima
# 5   S/ 2,000                            Pueblo Libre, Lima
# 6   S/ 2,300                            Pueblo Libre, Lima
# 7   S/ 2,600                            Pueblo Libre, Lima
# 8   S/ 2,600                            Pueblo Libre, Lima
# 9   S/ 2,000                    Mateo Salado, Pueblo Libre
# 10  S/ 2,300                            Pueblo Libre, Lima
# 11  S/ 2,000                            Pueblo Libre, Lima
# 12  S/ 2,350                            Pueblo Libre, Lima
# 13  S/ 2,000                      Isla Verde, Pueblo Libre
# 14  S/ 2,500                            Pueblo Libre, Lima
# ...
