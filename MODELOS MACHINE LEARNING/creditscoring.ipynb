# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df=pd.read_csv("G:\Mi unidad\IAN\APRENDIENDO\BASES DE DATOS\RIESGOCREDITICIO.csv")

# %%
df=df.rename(columns={'clientid': 'CLIENTE_ID',"income":"INGRESOS","age":"EDAD","loan":"PRESTAMO","default":"ESTADO"})

print(df.head(),df.shape,df.info())

# VEMOS LOS DATOS NULOS
print((df.isnull().sum()* 100 / len(df)))

#ELIMINAMOS NULOS
df=df.dropna()

# DESCRIBIMOS DATOS
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1997 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CLIENTE_ID  1997 non-null   int64
#  1   INGRESOS    1997 non-null   float64
#  2   EDAD        1997 non-null   float64
#  3   PRESTAMO    1997 non-null   float64
#  4   ESTADO      1997 non-null   int64
# dtypes: float64(3), int64(2)
# memory usage: 93.6 KB
#    CLIENTE_ID      INGRESOS       EDAD     PRESTAMO  ESTADO
# 0           1  66155.925095  59.017015  8106.532131       0
# 1           2  34415.153966  48.117153  6564.745018       0
# 2           3  57317.170063  63.108049  8020.953296       0
# 3           4  42709.534201  45.751972  6103.642260       0
# 4           5  66952.688845  18.584336  8770.099235       1 (1997, 5) None
# CLIENTE_ID    0.0
# INGRESOS      0.0
# EDAD          0.0
# PRESTAMO      0.0
# ESTADO        0.0
# dtype: float64
# ...
